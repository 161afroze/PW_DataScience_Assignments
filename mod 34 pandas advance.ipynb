# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
course_name=['Data Science','Machine Learning','Big Data','Data Engineer']
duration=[2,3,6,4]
df=pd.DataFrame(data={'course_name':course_name,'duration':duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# ### Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
df.iloc[[1]]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %% [markdown]
# ### Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?

# %% [markdown]
# Through the means of loc() we can perform boolean indexing, string indexing , integer indexing bu t
#
#
# Through the means of iloc() we can only perform integer indexing .

# %% [markdown]
# ### Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].
#
# Did you observe any difference in both the outputs? If so then explain it.

# %%
new_df=df.reindex([3,0,1,2])
print(new_df)
print("--------------------------")
print(new_df.loc[2])
print("--------------------------")
print(new_df.iloc[1])
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# --------------------------
# course_name    Big Data
# duration              6
# Name: 2, dtype: object
# --------------------------
# course_name    Data Science
# duration                  2
# Name: 0, dtype: object

# %% [markdown]
# the changes was loc() method printed the row with 2 as the index ( which is a string indexing)
#
# but whereas the iloc() method printed the actual 2 indexed( in programming )( 1 based)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np 
columns=['column_1','column_2','column_3','column_4','column_5','column_6']
indices=[1,2,3,4,5,6]

df1=pd.DataFrame(np.random.rand(6,6),columns=columns,index=indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.843347  0.654403  0.920799  0.927851  0.596042  0.157141
# 2  0.780582  0.886865  0.334432  0.932904  0.874301  0.734455
# 3  0.447487  0.222670  0.792079  0.343525  0.686423  0.668777
# 4  0.709805  0.276316  0.850516  0.598338  0.902083  0.010654
# 5  0.482035  0.455426  0.510321  0.795863  0.165550  0.285353
# 6  0.392749  0.030302  0.420954  0.016819  0.497012  0.652948

# %% [markdown]
# ### Q4. Write a code to find the following statistical measurements for the above dataframe df1:
# (i) mean of each and every column present in the dataframe.
#
# (ii) standard deviation of column, ‘column_2’

# %%
df1.mean()
# Out:
# column_1    0.609334
# column_2    0.420997
# column_3    0.638184
# column_4    0.602550
# column_5    0.620235
# column_6    0.418221
# dtype: float64

# %%
df1['column_2'].std()
# Out:
# 0.31164275144555986

# %% [markdown]
# ### Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find themean of column, column_2.If you are getting errors in executing it then explain why.
#
# [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
df1.loc[2,'column_2']='shaa'

# %%
df1['column_2'].mean()

# this will throw and error becasuse we cannot add the float value and the stirng value
# due to this it will throw and error

# %% [markdown]
# ### Q6. What do you understand about the windows function in pandas and list the types of windows functions?

# %% [markdown]
# ### Q7. Write a code to print only the current month and year at the time of answering this question.
#
# [Hint: Use pandas.datetime function]

# %%
print(pd.Timestamp.now().year)
print(pd.Timestamp.now().month)
# Out:
# 2024
# 6

# %% [markdown]
# ### Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) andcalculates the difference between them in days, hours, and minutes using Pandas time delta. Theprogram should prompt the user to enter the dates and display the result.

# %%
import pandas as pd

# Function to calculate the difference between two dates
def calculate_date_difference(date1, date2):
    # Convert input strings to pandas datetime objects
    date1 = pd.to_datetime(date1)
    date2 = pd.to_datetime(date2)
    
    # Calculate the difference
    delta = date2 - date1
    
    # Extract days, hours, and minutes from the time difference
    days = delta.days
    seconds = delta.seconds
    hours = seconds // 3600
    minutes = (seconds % 3600) // 60
    
    return days, hours, minutes

# Main program
def main():
    # Prompt the user to enter two dates
    date1 = input("Enter the first date (YYYY-MM-DD): ")
    date2 = input("Enter the second date (YYYY-MM-DD): ")
    
    # Calculate the difference
    days, hours, minutes = calculate_date_difference(date1, date2)
    
    # Display the result
    print(f"The difference between {date1} and {date2} is {days} days, {hours} hours, and {minutes} minutes.")

# Run the main program
if __name__ == "__main__":
    main()
